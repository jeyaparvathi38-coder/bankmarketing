# %% [markdown]
# # Bank Marketing - Classification

# %% [markdown]
# ## Data Import

# %%
pip install ucimlrepo
# Out:
# Requirement already satisfied: ucimlrepo in c:\users\asus\anaconda3\lib\site-packages (0.0.7)
# Requirement already satisfied: pandas>=1.0.0 in c:\users\asus\anaconda3\lib\site-packages (from ucimlrepo) (2.3.3)
# Requirement already satisfied: certifi>=2020.12.5 in c:\users\asus\anaconda3\lib\site-packages (from ucimlrepo) (2026.1.4)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\asus\anaconda3\lib\site-packages (from pandas>=1.0.0->ucimlrepo) (2.3.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\asus\anaconda3\lib\site-packages (from pandas>=1.0.0->ucimlrepo) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\asus\anaconda3\lib\site-packages (from pandas>=1.0.0->ucimlrepo) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\asus\anaconda3\lib\site-packages (from pandas>=1.0.0->ucimlrepo) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\asus\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.0.0->ucimlrepo) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from ucimlrepo import fetch_ucirepo

# fetch dataset
bank_marketing = fetch_ucirepo(id=222)

# data (as pandas dataframes)
X = bank_marketing.data.features
y = bank_marketing.data.targets

# %%
type(X)
# Out:
# pandas.core.frame.DataFrame

# %%
type(y)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ## Exploratory Data Analysis

# %%
# Combine features and target in a single dataframe
import pandas as pd

data = pd.concat([X, y], axis=1)  # Join 2 dataframes into 1
data.head()
# Out:
#    age           job  marital  education default  balance housing loan  \
# 0   58    management  married   tertiary      no     2143     yes   no
# 1   44    technician   single  secondary      no       29     yes   no
# 2   33  entrepreneur  married  secondary      no        2     yes  yes
# 3   47   blue-collar  married        NaN      no     1506     yes   no
# 4   33           NaN   single        NaN      no        1      no   no
#
#   contact  day_of_week month  duration  campaign  pdays  previous poutcome   y
# 0     NaN            5   may       261         1     -1         0      NaN  no
# 1     NaN            5   may       151         1     -1         0      NaN  no
# 2     NaN            5   may        76         1     -1         0      NaN  no
# 3     NaN            5   may        92         1     -1         0      NaN  no
# 4     NaN            5   may       198         1     -1         0      NaN  no

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45211 entries, 0 to 45210
# Data columns (total 17 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   age          45211 non-null  int64
#  1   job          44923 non-null  object
#  2   marital      45211 non-null  object
#  3   education    43354 non-null  object
#  4   default      45211 non-null  object
#  5   balance      45211 non-null  int64
#  6   housing      45211 non-null  object
#  7   loan         45211 non-null  object
#  8   contact      32191 non-null  object
#  9   day_of_week  45211 non-null  int64
#  10  month        45211 non-null  object
#  11  duration     45211 non-null  int64
#  12  campaign     45211 non-null  int64
#  13  pdays        45211 non-null  int64
#  14  previous     45211 non-null  int64
#  15  poutcome     8252 non-null   object
#  16  y            45211 non-null  object
# dtypes: int64(7), object(10)
# memory usage: 5.9+ MB

# %%
# Removing `poutcome` because of large amount of null values
data = data.drop(columns=['poutcome'])

# %%
data.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'balance', 'housing',
#        'loan', 'contact', 'day_of_week', 'month', 'duration', 'campaign',
#        'pdays', 'previous', 'y'],
#       dtype='object')

# %%
# Replacing null values
data['job'].value_counts(normalize=True)
# Out:
# job
# blue-collar      0.216637
# management       0.210538
# technician       0.169112
# admin.           0.115108
# services         0.092469
# retired          0.050397
# self-employed    0.035149
# entrepreneur     0.033101
# unemployed       0.029005
# housemaid        0.027603
# student          0.020880
# Name: proportion, dtype: float64

# %%
data['job'].mode()
# Out:
# 0    blue-collar
# Name: job, dtype: object

# %%
data['job'].mode()[0]
# Out:
# 'blue-collar'

# %%
data['job'] = data['job'].fillna(data['job'].mode()[0])

# %%
data['job'].isnull().sum() # checking if nulls are replaced
# Out:
# np.int64(0)

# %%
data['education'] = data['education'].fillna(data['education'].mode()[0])
data['education'].isnull().sum()
# Out:
# np.int64(0)

# %%
data['contact'] = data['contact'].fillna(data['contact'].mode()[0])
data['contact'].isnull().sum()
# Out:
# np.int64(0)

# %%
# Checking for null values in the entire dataframe
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45211 entries, 0 to 45210
# Data columns (total 16 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   age          45211 non-null  int64
#  1   job          45211 non-null  object
#  2   marital      45211 non-null  object
#  3   education    45211 non-null  object
#  4   default      45211 non-null  object
#  5   balance      45211 non-null  int64
#  6   housing      45211 non-null  object
#  7   loan         45211 non-null  object
#  8   contact      45211 non-null  object
#  9   day_of_week  45211 non-null  int64
#  10  month        45211 non-null  object
#  11  duration     45211 non-null  int64
#  12  campaign     45211 non-null  int64
#  13  pdays        45211 non-null  int64
#  14  previous     45211 non-null  int64
#  15  y            45211 non-null  object
# dtypes: int64(7), object(9)
# memory usage: 5.5+ MB

# %%
subscr_by_age = data.groupby('y')['age'].mean()
subscr_by_age
# Out:
# y
# no     40.838986
# yes    41.670070
# Name: age, dtype: float64

# %%
subscr_by_age = subscr_by_age.reset_index()
subscr_by_age
# Out:
#      y        age
# 0   no  40.838986
# 1  yes  41.670070

# %%
import seaborn as sns
import matplotlib.pyplot as plt


plt.style.use('fivethirtyeight')

# %%
plt.rcParams['font.family'] = 'Arial'
plt.rcParams['legend.fontsize'] = 8  # Legend font size
plt.rcParams['legend.title_fontsize'] = 10  # Legend Title font size
plt.rcParams['axes.labelsize'] = 10  # X and Y-axis label size
plt.rcParams['axes.titlesize'] = 12  # Plot title size
plt.rcParams['xtick.labelsize'] = 8 # X-tick font size
plt.rcParams['ytick.labelsize'] = 8  # Y-tick font size

# %%
sns.barplot(data=subscr_by_age,
            x='y',
            y='age')
plt.title("Term Subscription by Average Age")
# Out:
# Text(0.5, 1.0, 'Term Subscription by Average Age')

# %%
subscr_by_edu = data.groupby('y')['education'].value_counts(normalize=True).reset_index()
subscr_by_edu
# Out:
#      y  education  proportion
# 0   no  secondary    0.560017
# 1   no   tertiary    0.283177
# 2   no    primary    0.156806
# 3  yes  secondary    0.510872
# 4  yes   tertiary    0.377387
# 5  yes    primary    0.111741

# %%
sns.barplot(data=subscr_by_edu,
            x='y',
            y='proportion',
            hue='education')
# Out:
# <Axes: xlabel='y', ylabel='proportion'>

# %%
# TODO

# %% [markdown]
# ## Train-test Split

# %%
features = data.drop(columns=['y'])
target = data['y']

# %%
target.value_counts(normalize=True)
# Out:
# y
# no     0.883015
# yes    0.116985
# Name: proportion, dtype: float64

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(features,
                                                    target,
                                                    test_size=0.25,
                                                    stratify=target)
# stratify=target is to maintain target's distribution after split

# %%
X_train.shape
# Out:
# (33908, 15)

# %%
y_train.shape
# Out:
# (33908,)

# %%
y_train.value_counts(normalize=True)
# Out:
# y
# no     0.883007
# yes    0.116993
# Name: proportion, dtype: float64

# %%
X_test.shape
# Out:
# (11303, 15)

# %%
y_test.shape
# Out:
# (11303,)

# %%
y_test.value_counts(normalize=True)
# Out:
# y
# no     0.88304
# yes    0.11696
# Name: proportion, dtype: float64

# %% [markdown]
# ## Preprocessing

# %%
from sklearn.preprocessing import OrdinalEncoder, One  # for encoding categorical columns
from sklearn.preprocessing import StandardScaler  # for scaling numerical columns
from sklearn.compose import make_column_selector as selector  # selecting column names
from sklearn.compose import ColumnTransformer  # Transform categoric and numeric columns
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[70], line 1
# ----> 1 from sklearn.preprocessing import OrdinalEncoder, One  # for encoding categorical columns
#       2 from sklearn.preprocessing import StandardScaler  # for scaling numerical columns
#       3 from sklearn.compose import make_column_selector as selector  # selecting column names
#
# ImportError: cannot import name 'One' from 'sklearn.preprocessing' (c:\Users\Asus\anaconda3\Lib\site-packages\sklearn\preprocessing\__init__.py)

# %%
numeric_selector = selector(dtype_include='number')
categoric_selector = selector(dtype_include='str')

# %%
numeric_columns = numeric_selector(features)
categoric_columns = categoric_selector(features)

# %%
numeric_columns
# Out:
# ['age', 'balance', 'day_of_week', 'duration', 'campaign', 'pdays', 'previous']

# %%
categoric_columns
# Out:
# ['job',
#  'marital',
#  'education',
#  'default',
#  'housing',
#  'loan',
#  'contact',
#  'month']

# %%
preprocessor = ColumnTransformer(
    [('num', StandardScaler(), numeric_columns),
     ('cat', OrdinalEncoder(), categoric_columns)
    ])
preprocessor
# Out:
# ColumnTransformer(transformers=[('num', StandardScaler(),
#                                  ['age', 'balance', 'day_of_week', 'duration',
#                                   'campaign', 'pdays', 'previous']),
#                                 ('cat', OrdinalEncoder(),
#                                  ['job', 'marital', 'education', 'default',
#                                   'housing', 'loan', 'contact', 'month'])])

# %% [markdown]
# ## Build the Model

# %%
from sklearn.pipeline import Pipeline
from sklearn.neighbors import KNeighborsClassifier

# %%
knn_model = Pipeline(
    [('preprocessor', preprocessor),
     ('knn', KNeighborsClassifier())
    ])

# %%
knn_model
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num', StandardScaler(),
#                                                   ['age', 'balance',
#                                                    'day_of_week', 'duration',
#                                                    'campaign', 'pdays',
#                                                    'previous']),
#                                                  ('cat', OrdinalEncoder(),
#                                                   ['job', 'marital',
#                                                    'education', 'default',
#                                                    'housing', 'loan', 'contact',
#                                                    'month'])])),
#                 ('knn', KNeighborsClassifier())])

# %% [markdown]
# ## Train the Model

# %%
from sklearn.model_selection import GridSearchCV

# %%
grid_search_knn = GridSearchCV(knn_model,
                               param_grid={"knn__n_neighbors": [3, 5, 8, 10],
                                           "knn__weights": ['uniform', 'distance'],
                                           "knn__metric": ['manhattan', 'euclidean']},
                               scoring='balanced_accuracy')

# %%
grid_search_knn
# Out:
# GridSearchCV(estimator=Pipeline(steps=[('preprocessor',
#                                         ColumnTransformer(transformers=[('num',
#                                                                          StandardScaler(),
#                                                                          ['age',
#                                                                           'balance',
#                                                                           'day_of_week',
#                                                                           'duration',
#                                                                           'campaign',
#                                                                           'pdays',
#                                                                           'previous']),
#                                                                         ('cat',
#                                                                          OrdinalEncoder(),
#                                                                          ['job',
#                                                                           'marital',
#                                                                           'education',
#                                                                           'default',
#                                                                           'housing',
#                                                                           'loan',
#                                                                           'contact',
#                                                                           'month'])])),
#                                        ('knn', KNeighborsClassifier())]),
#              param_grid={'knn__metric': ['manhattan', 'euclidean'],
#                          'knn__n_neighbors': [3, 5, 8, 10],
#                          'knn__weights': ['uniform', 'distance']},
#              scoring='balanced_accuracy')

# %%
grid_search_knn.fit(X_train, y_train)
# Out:
# GridSearchCV(estimator=Pipeline(steps=[('preprocessor',
#                                         ColumnTransformer(transformers=[('num',
#                                                                          StandardScaler(),
#                                                                          ['age',
#                                                                           'balance',
#                                                                           'day_of_week',
#                                                                           'duration',
#                                                                           'campaign',
#                                                                           'pdays',
#                                                                           'previous']),
#                                                                         ('cat',
#                                                                          OrdinalEncoder(),
#                                                                          ['job',
#                                                                           'marital',
#                                                                           'education',
#                                                                           'default',
#                                                                           'housing',
#                                                                           'loan',
#                                                                           'contact',
#                                                                           'month'])])),
#                                        ('knn', KNeighborsClassifier())]),
#              param_grid={'knn__metric': ['manhattan', 'euclidean'],
#                          'knn__n_neighbors': [3, 5, 8, 10],
#                          'knn__weights': ['uniform', 'distance']},
#              scoring='balanced_accuracy')

# %%
dir(grid_search_knn)
# Out:
# ['__abstractmethods__',
#  '__annotations__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__firstlineno__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setstate__',
#  '__sizeof__',
#  '__sklearn_clone__',
#  '__sklearn_tags__',
#  '__static_attributes__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_abc_impl',
#  '_check_refit_for_multimetric',
#  '_check_scorers_accept_sample_weight',
#  '_doc_link_module',
#  '_doc_link_template',
#  '_doc_link_url_param_generator',
#  '_format_results',
#  '_get_class_level_metadata_request_values',
#  '_get_doc_link',
#  '_get_metadata_request',
#  '_get_param_names',
#  '_get_params_html',
#  '_get_routed_params_for_fit',
#  '_get_scorers',
#  '_html_repr',
#  '_parameter_constraints',
#  '_repr_html_',
#  '_repr_html_inner',
#  '_repr_mimebundle_',
#  '_run_search',
#  '_select_best_index',
#  '_sk_visual_block_',
#  '_validate_params',
#  'best_estimator_',
#  'best_index_',
#  'best_params_',
#  'best_score_',
#  'classes_',
#  'cv',
#  'cv_results_',
#  'error_score',
#  'estimator',
#  'feature_names_in_',
#  'fit',
#  'get_metadata_routing',
#  'get_params',
#  'multimetric_',
#  'n_features_in_',
#  'n_jobs',
#  'n_splits_',
#  'param_grid',
#  'pre_dispatch',
#  'predict',
#  'predict_proba',
#  'refit',
#  'refit_time_',
#  'return_train_score',
#  'score',
#  'scorer_',
#  'scoring',
#  'set_params',
#  'verbose']

# %%
pd.DataFrame(grid_search_knn.cv_results_)
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.267195      0.055681         2.233619        0.073998
# 1        0.254884      0.032777         2.124521        0.022879
# 2        0.239490      0.002943         2.479690        0.085772
# 3        0.246191      0.012761         2.467374        0.058040
# 4        0.239793      0.006303         2.725070        0.052917
# 5        0.237651      0.001763         2.819413        0.151765
# 6        0.241226      0.009843         3.054396        0.325607
# 7        0.247758      0.014462         3.355708        0.274165
# 8        0.295875      0.078329         2.122974        0.279517
# 9        0.292767      0.044094         2.000228        0.134150
# 10       0.286160      0.084774         2.425526        0.162461
# 11       0.312544      0.066705         2.931182        0.706817
# 12       0.416654      0.151396         4.905405        1.929801
# 13       0.320846      0.090950         3.125579        0.720453
# 14       0.243327      0.011934         2.282930        0.241408
# 15       0.230959      0.003878         2.138306        0.038336
#
#    param_knn__metric  param_knn__n_neighbors param_knn__weights  \
# 0          manhattan                       3            uniform
# 1          manhattan                       3           distance
# 2          manhattan                       5            uniform
# 3          manhattan                       5           distance
# 4          manhattan                       8            uniform
# 5          manhattan                       8           distance
# 6          manhattan                      10            uniform
# 7          manhattan                      10           distance
# 8          euclidean                       3            uniform
# 9          euclidean                       3           distance
# 10         euclidean                       5            uniform
# 11         euclidean                       5           distance
# 12         euclidean                       8            uniform
# 13         euclidean                       8           distance
# 14         euclidean                      10            uniform
# 15         euclidean                      10           distance
#
#                                                params  split0_test_score  \
# 0   {'knn__metric': 'manhattan', 'knn__n_neighbors...           0.644827
# 1   {'knn__metric': 'manhattan', 'knn__n_neighbors...           0.648026
# 2   {'knn__metric': 'manhattan', 'knn__n_neighbors...           0.632775
# 3   {'knn__metric': 'manhattan', 'knn__n_neighbors...           0.633535
# 4   {'knn__metric': 'manhattan', 'knn__n_neighbors...           0.575567
# 5   {'knn__metric': 'manhattan', 'knn__n_neighbors...           0.611913
# 6   {'knn__metric': 'manhattan', 'knn__n_neighbors...           0.568753
# 7   {'knn__metric': 'manhattan', 'knn__n_neighbors...           0.599832
# 8   {'knn__metric': 'euclidean', 'knn__n_neighbors...           0.659430
# 9   {'knn__metric': 'euclidean', 'knn__n_neighbors...           0.662249
# 10  {'knn__metric': 'euclidean', 'knn__n_neighbors...           0.635055
# 11  {'knn__metric': 'euclidean', 'knn__n_neighbors...           0.637577
# 12  {'knn__metric': 'euclidean', 'knn__n_neighbors...           0.593444
# 13  {'knn__metric': 'euclidean', 'knn__n_neighbors...           0.620415
# 14  {'knn__metric': 'euclidean', 'knn__n_neighbors...           0.585785
# 15  {'knn__metric': 'euclidean', 'knn__n_neighbors...           0.613842
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.622173           0.638765           0.639547
# 1            0.626042           0.640532           0.640094
# 2            0.614929           0.625429           0.616572
# 3            0.619845           0.626150           0.619475
# 4            0.566110           0.578712           0.570160
# 5            0.602283           0.618329           0.607645
# 6            0.559350           0.575473           0.566710
# 7            0.587876           0.611645           0.597502
# 8            0.628150           0.648308           0.651553
# 9            0.628408           0.650493           0.652480
# 10           0.620148           0.642620           0.632269
# 11           0.622712           0.644805           0.634624
# 12           0.580274           0.593961           0.585643
# 13           0.606454           0.638236           0.620865
# 14           0.571792           0.586693           0.578745
# 15           0.605522           0.629869           0.611733
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.641096         0.637282        0.007837                4
# 1            0.643664         0.639672        0.007381                3
# 2            0.625892         0.623120        0.006576                8
# 3            0.631362         0.626073        0.005762                7
# 4            0.576882         0.573486        0.004661               15
# 5            0.617808         0.611595        0.006105               11
# 6            0.572970         0.568651        0.005576               16
# 7            0.607127         0.600796        0.008204               12
# 8            0.649226         0.647333        0.010360                2
# 9            0.650868         0.648899        0.011112                1
# 10           0.630582         0.632135        0.007274                6
# 11           0.634114         0.634767        0.007133                5
# 12           0.589965         0.588657        0.005140               13
# 13           0.625020         0.622198        0.010178                9
# 14           0.581684         0.580940        0.005397               14
# 15           0.618743         0.615942        0.008155               10

# %%
optimal_model = grid_search_knn.best_estimator_
optimal_model
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num', StandardScaler(),
#                                                   ['age', 'balance',
#                                                    'day_of_week', 'duration',
#                                                    'campaign', 'pdays',
#                                                    'previous']),
#                                                  ('cat', OrdinalEncoder(),
#                                                   ['job', 'marital',
#                                                    'education', 'default',
#                                                    'housing', 'loan', 'contact',
#                                                    'month'])])),
#                 ('knn',
#                  KNeighborsClassifier(metric='euclidean', n_neighbors=3,
#                                       weights='distance'))])

# %% [markdown]
# ## Model Evaluation

# %%
y_pred = optimal_model.predict(X_test)

# %%
from sklearn.metrics import balanced_accuracy_score
from sklearn.metrics import precision_score, recall_score

# %%
balanced_accuracy = balanced_accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred, pos_label='yes')
recall = recall_score(y_test, y_pred, pos_label='yes')

# %%
print("Balanced accuracy", balanced_accuracy)
print("Precision", precision)
print("Recall", recall)
# Out:
# Balanced accuracy 0.6547197239050717
# Precision 0.5404454865181711
# Recall 0.348714069591528

# %%
from sklearn.metrics import ConfusionMatrixDisplay

ConfusionMatrixDisplay.from_estimator(grid_search_knn,
                                      X_test,
                                      y_test)
plt.grid(False)

# %% [markdown]
# ## How to optimize?
#
# * Instead of using all the columns, use only selected useful columns
# * Instead of using StandardScaler, use some other numeric scaler or don't scale it.
# * Instead of using OrdinalEncoder, use some other encoder.
# * Expand the range of `param_grid`
